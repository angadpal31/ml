# %% [markdown]
# # Week 1 Assignmnet

# %% [markdown]
# # New Section

# %% [markdown]
# For this week's assignment, you are expected to solve all the questions asked. You can google if there's something that you are not sure about. However, copying code from other websites is not allowed.
#
#
#
# *   This is a graded assignment
# *   Questions are easy/medium
# *   Total points: 20
#
# ---
# **Questions**
#
#
# 1.   load the dataset and split it using ";" (1 point)
# 2.   Rename the columns according to the first row (1 point)
# 3.   Generate a bar graph between age and marital columns (2 points)
# 4.   extract the set of different education levels in the dataset (1 point)
# 5.   List out all the people who are married and don't own a house (2 points)
# 6.   Check if values are missing in any dataset. If yes, please list out how many. Also, eliminate those datapoints. (4 points)
# 7.   List out people with the balance in the negative (1 point)
# 8.   Generate a scatter plot between age and balance. Do you see any patterns? (2 points)
# 9.   How many people are entrepreneurs and have balance in access of 1000? (2 points)
# 10.   List the people who have secondary level education, are entrepreneurs but have a balance less than 1000. (4 points)
#
#
# ---
# **How do I answer a question**
#
#
# * Each question should have a cell.
# * Each cell should begin with a markdown stating the question number and the question in the markdown. If you don't know what it is please make a quick google search _how to add markdown in google colab_
# * If the question has a subjective question please write your answer using "#" (comments)
#
# _Template of the solution is attached below_
#
#
# ---
#
# > Don't forget to have fun ;)
#
# > we'll have a discussion in the hands-on session if required

# %% [markdown]
# ## Template of solution
# ## 1. This is question number on

# %%
#write your soluton here
# if there's a subjective question please write it here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Q1
df = pd.read_csv("bank-full.csv",sep=';')
print(df)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 0       58     management   married   tertiary      no     2143     yes   no
# 1       44     technician    single  secondary      no       29     yes   no
# 2       33   entrepreneur   married  secondary      no        2     yes  yes
# 3       47    blue-collar   married    unknown      no     1506     yes   no
# 4       33        unknown    single    unknown      no        1      no   no
# 5       35     management   married   tertiary      no      231     yes   no
# 6       28     management    single   tertiary      no      447     yes  yes
# 7       42   entrepreneur  divorced   tertiary     yes        2     yes   no
# 8       58        retired   married    primary      no      121     yes   no
# 9       43     technician    single  secondary      no      593     yes   no
# 10      41         admin.  divorced  secondary      no      270     yes   no
# ...

# %%
#Q2
new_header=df.iloc[0]
df1=df[1:]
df1.columns=new_header
df1.head()
# Out:
# 0  58    management  married   tertiary  no  2143  yes   no  unknown  5  may  \
# 1  44    technician   single  secondary  no    29  yes   no  unknown  5  may
# 2  33  entrepreneur  married  secondary  no     2  yes  yes  unknown  5  may
# 3  47   blue-collar  married    unknown  no  1506  yes   no  unknown  5  may
# 4  33       unknown   single    unknown  no     1   no   no  unknown  5  may
# 5  35    management  married   tertiary  no   231  yes   no  unknown  5  may
#
# 0  261  1  -1  0  unknown  no
# 1  151  1  -1  0  unknown  no
# 2   76  1  -1  0  unknown  no
# 3   92  1  -1  0  unknown  no
# 4  198  1  -1  0  unknown  no
# 5  139  1  -1  0  unknown  no

# %% [markdown]
# # New Section

# %% [markdown]
# ## Please run the code below to load the dataset into the runtime

# %%
# load the modules
# !wget -q https://github.com/skathirmani/datasets/raw/master/bank-full.csv

# %%
#Q3
#ax1 = df[['age']]
#ax2=df[['marital']]
#index=np.arrange(len(age))
#plt.bar([ax1,ax2)
#plt.show()

# %%
#Q4
sd=df["education"]
print (sd)
# Out:
# 0         tertiary
# 1        secondary
# 2        secondary
# 3          unknown
# 4          unknown
# 5         tertiary
# 6         tertiary
# 7         tertiary
# 8          primary
# 9        secondary
# 10       secondary
# 11       secondary
# 12       secondary
# 13         unknown
# 14       secondary
# 15         primary
# 16         unknown
# 17         primary
# 18         primary
# 19       secondary
# 20       secondary
# 21        tertiary
# 22         primary
# 23       secondary
# 24         primary
# 25       secondary
# 26        tertiary
# 27       secondary
# 28       secondary
# 29       secondary
#            ...
# 45181    secondary
# 45182    secondary
# 45183      primary
# 45184    secondary
# 45185     tertiary
# 45186      unknown
# 45187    secondary
# 45188    secondary
# 45189    secondary
# 45190    secondary
# 45191     tertiary
# 45192     tertiary
# 45193     tertiary
# 45194     tertiary
# 45195    secondary
# 45196    secondary
# ...

# %%
#Q5
df.query("marital=='married' & housing!='no'")
# Out:
#        age            job  marital  education default  balance housing loan  \
# 0       58     management  married   tertiary      no     2143     yes   no
# 2       33   entrepreneur  married  secondary      no        2     yes  yes
# 3       47    blue-collar  married    unknown      no     1506     yes   no
# 5       35     management  married   tertiary      no      231     yes   no
# 8       58        retired  married    primary      no      121     yes   no
# 12      53     technician  married  secondary      no        6     yes   no
# 13      58     technician  married    unknown      no       71     yes   no
# 14      57       services  married  secondary      no      162     yes   no
# 15      51        retired  married    primary      no      229     yes   no
# 17      57    blue-collar  married    primary      no       52     yes   no
# 18      60        retired  married    primary      no       60     yes   no
# ...

# %%
#Q6
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
#Q7
df[df["balance"]<0]
# Out:
#        age            job   marital  education default  balance housing loan  \
# 25      44         admin.   married  secondary      no     -372     yes   no
# 28      46     management    single  secondary      no     -246     yes   no
# 36      25    blue-collar   married  secondary      no       -7     yes   no
# 37      53     technician   married  secondary      no       -3      no   no
# 45      36         admin.    single    primary      no     -171     yes   no
# 46      58  self-employed   married   tertiary      no     -364     yes   no
# 51      48     management  divorced   tertiary      no     -244     yes   no
# 53      42         admin.    single  secondary      no      -76     yes   no
# 54      24     technician    single  secondary      no     -103     yes  yes
# 94      57   entrepreneur  divorced  secondary      no      -37      no   no
# 100     44    blue-collar   married  secondary      no     -674     yes   no
# ...

# %%
#Q8
#ax2 = df.plot.scatter(x='marital', y='age', c='species',colormap='viridis')

# %%
#Q9
df.query("balance > 1000 & job == 'entrepreneur'")
# Out:
#        age           job   marital  education default  balance housing loan  \
# 357     33  entrepreneur    single   tertiary      no     1068     yes   no
# 414     36  entrepreneur   married   tertiary      no     1169     yes   no
# 695     44  entrepreneur   married   tertiary      no     1631     yes   no
# 947     46  entrepreneur   married    unknown      no     1481     yes   no
# 1020    36  entrepreneur   married   tertiary      no     1722     yes   no
# 1236    34  entrepreneur   married   tertiary      no    10350     yes   no
# 1711    38  entrepreneur   married  secondary      no     2139     yes   no
# 1788    32  entrepreneur    single   tertiary      no     6259     yes   no
# 1902    39  entrepreneur   married  secondary      no     1261     yes   no
# 2005    37  entrepreneur  divorced  secondary      no     1190     yes   no
# 2705    40  entrepreneur   married   tertiary      no     1089     yes  yes
# ...

# %%
#Q10
df.query("balance <1000 & job == 'entrepreneur'& education=='secondary'")
# Out:
#        age           job   marital  education default  balance housing loan  \
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 27      52  entrepreneur   married  secondary      no      113     yes  yes
# 94      57  entrepreneur  divorced  secondary      no      -37      no   no
# 222     35  entrepreneur  divorced  secondary      no      -69     yes   no
# 232     57  entrepreneur   married  secondary      no      294     yes   no
# 256     59  entrepreneur  divorced  secondary      no      901     yes   no
# 273     56  entrepreneur  divorced  secondary      no      155      no   no
# 515     49  entrepreneur   married  secondary      no      167     yes  yes
# 562     35  entrepreneur   married  secondary     yes      204     yes   no
# 576     53  entrepreneur   married  secondary      no      288      no   no
# 837     45  entrepreneur   married  secondary      no       68     yes   no
# ...
